# %% [markdown]
# # Predict Premier League Matches

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

pd.options.display.max_columns = None

# %% [markdown]
# ## Data Understanding

# %%
# Import Data
df1 = pd.read_csv('D:\GitHub\Streamlit-Premier-League\History Matches\epl_06_07.csv')
df2 = pd.read_csv('D:\GitHub\Streamlit-Premier-League\History Matches\epl_07_08.csv')
df3 = pd.read_csv('D:\GitHub\Streamlit-Premier-League\History Matches\epl_08_09.csv')
df4 = pd.read_csv('D:\GitHub\Streamlit-Premier-League\History Matches\epl_09_10.csv')
df5 = pd.read_csv('D:\GitHub\Streamlit-Premier-League\History Matches\epl_10_11.csv')
df6 = pd.read_csv('D:\GitHub\Streamlit-Premier-League\History Matches\epl_11_12.csv')
df7 = pd.read_csv('D:\GitHub\Streamlit-Premier-League\History Matches\epl_12_13.csv')
df8 = pd.read_csv('D:\GitHub\Streamlit-Premier-League\History Matches\epl_13_14.csv')
df9 = pd.read_csv('D:\GitHub\Streamlit-Premier-League\History Matches\epl_14_15.csv')
df10 = pd.read_csv('D:\GitHub\Streamlit-Premier-League\History Matches\epl_15_16.csv')
df11 = pd.read_csv('D:\GitHub\Streamlit-Premier-League\History Matches\epl_16_17.csv')
df12 = pd.read_csv('D:\GitHub\Streamlit-Premier-League\History Matches\epl_17_18.csv')
df13 = pd.read_csv('D:\GitHub\Streamlit-Premier-League\History Matches\epl_18_19.csv')
df14 = pd.read_csv('D:\GitHub\Streamlit-Premier-League\History Matches\epl_19_20.csv')
df15 = pd.read_csv('D:\GitHub\Streamlit-Premier-League\History Matches\epl_20_21.csv')
df16 = pd.read_csv('D:\GitHub\Streamlit-Premier-League\History Matches\epl_21_22.csv')
df17 = pd.read_csv('D:\GitHub\Streamlit-Premier-League\History Matches\epl_22_23.csv')

# %%
# Merge dataset
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17], ignore_index=True)

# %%
df.columns
# Out:
# Index(['date', 'season', 'venue', 'home_team', 'away_team', 'ht_home_score',
#        'ht_away_score', 'home_score', 'away_score', 'home_possession_%',
#        'away_possession_%', 'home_shots_on_target', 'away_shots_on_target',
#        'home_shots', 'away_shots', 'home_touches', 'away_touches',
#        'home_passes', 'away_passes', 'home_tackles', 'away_tackles',
#        'home_clearances', 'away_clearances', 'home_corners', 'away_corners',
#        'home_offsides', 'away_offsides', 'home_yellow_cards',
#        'away_yellow_cards', 'home_red_cards', 'away_red_cards', 'home_fouls',
#        'away_fouls', 'referee'],
#       dtype='object')

# %%
df.head()
# Out:
#          date season                           venue         home_team  \
# 0  19/08/2006  06/07         Bramall Lane, Sheffield  Sheffield United
# 1  19/08/2006  06/07        Fratton Park, Portsmouth        Portsmouth
# 2  19/08/2006  06/07        Goodison Park, Liverpool           Everton
# 3  19/08/2006  06/07  Sports Direct Arena, Newcastle  Newcastle United
# 4  19/08/2006  06/07       Madejski Stadium, Reading           Reading
#
#           away_team  ht_home_score  ht_away_score  home_score  away_score  \
# 0         Liverpool              0              0           1           1
# 1  Blackburn Rovers              1              0           3           0
# 2           Watford              1              0           2           1
# 3    Wigan Athletic              1              0           2           1
# 4     Middlesbrough              2              2           3           2
#
#    home_possession_%  away_possession_%  home_shots_on_target  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6404 entries, 0 to 6403
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  6404 non-null   object
#  1   season                6404 non-null   object
#  2   venue                 6404 non-null   object
#  3   home_team             6404 non-null   object
#  4   away_team             6404 non-null   object
#  5   ht_home_score         6404 non-null   int64
#  6   ht_away_score         6404 non-null   int64
#  7   home_score            6404 non-null   int64
#  8   away_score            6404 non-null   int64
#  9   home_possession_%     6404 non-null   float64
#  10  away_possession_%     6404 non-null   float64
#  11  home_shots_on_target  6404 non-null   int64
#  12  away_shots_on_target  6404 non-null   int64
#  13  home_shots            6404 non-null   int64
#  14  away_shots            6404 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# date                    0
# season                  0
# venue                   0
# home_team               0
# away_team               0
# ht_home_score           0
# ht_away_score           0
# home_score              0
# away_score              0
# home_possession_%       0
# away_possession_%       0
# home_shots_on_target    0
# away_shots_on_target    0
# home_shots              0
# away_shots              0
# home_touches            0
# away_touches            0
# home_passes             0
# away_passes             0
# home_tackles            0
# away_tackles            0
# home_clearances         0
# away_clearances         0
# home_corners            0
# away_corners            0
# home_offsides           0
# away_offsides           0
# home_yellow_cards       0
# away_yellow_cards       0
# home_red_cards          0
# away_red_cards          0
# home_fouls              0
# away_fouls              0
# referee                 0
# dtype: int64

# %%
df.nunique()
# Out:
# date                    1786
# season                    17
# venue                     54
# home_team                 43
# away_team                 43
# ht_home_score              6
# ht_away_score              6
# home_score                10
# away_score                 9
# home_possession_%         66
# away_possession_%         66
# home_shots_on_target      18
# away_shots_on_target      16
# home_shots                43
# away_shots                34
# home_touches             631
# away_touches             613
# home_passes              621
# away_passes              616
# home_tackles              45
# away_tackles              46
# home_clearances           91
# away_clearances          104
# home_corners              21
# away_corners              20
# home_offsides             14
# away_offsides             13
# home_yellow_cards          8
# away_yellow_cards         10
# home_red_cards             3
# away_red_cards             3
# home_fouls                29
# ...

# %%
df.describe()
# Out:
#        ht_home_score  ht_away_score   home_score   away_score  \
# count    6404.000000    6404.000000  6404.000000  6404.000000
# mean        0.682074       0.519519     1.532324     1.178638
# std         0.836903       0.734309     1.317615     1.163076
# min         0.000000       0.000000     0.000000     0.000000
# 25%         0.000000       0.000000     1.000000     0.000000
# 50%         0.000000       0.000000     1.000000     1.000000
# 75%         1.000000       1.000000     2.000000     2.000000
# max         5.000000       5.000000     9.000000     9.000000
#
#        home_possession_%  away_possession_%  home_shots_on_target  \
# count        6404.000000        6404.000000           6404.000000
# mean            0.507739           0.483256              4.863054
# std             0.111097           0.111096              2.642441
# min             0.170000           0.170000              0.000000
# 25%             0.430000           0.410000              3.000000
# ...

# %% [markdown]
# ## Data Cleaning

# %%
# Tidak ada data yang duplikasi
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [date, season, venue, home_team, away_team, ht_home_score, ht_away_score, home_score, away_score, home_possession_%, away_possession_%, home_shots_on_target, away_shots_on_target, home_shots, away_shots, home_touches, away_touches, home_passes, away_passes, home_tackles, away_tackles, home_clearances, away_clearances, home_corners, away_corners, home_offsides, away_offsides, home_yellow_cards, away_yellow_cards, home_red_cards, away_red_cards, home_fouls, away_fouls, referee]
# Index: []

# %%
df.drop(['date', 'season', 'venue', 'referee'], axis=1, inplace=True)

# %%
df
# Out:
#              home_team          away_team  ht_home_score  ht_away_score  \
# 0     Sheffield United          Liverpool              0              0
# 1           Portsmouth   Blackburn Rovers              1              0
# 2              Everton            Watford              1              0
# 3     Newcastle United     Wigan Athletic              1              0
# 4              Reading      Middlesbrough              2              2
# ...                ...                ...            ...            ...
# 6399   Manchester City            Arsenal              2              0
# 6400          West Ham          Liverpool              1              1
# 6401       Southampton        Bournemouth              0              0
# 6402           Everton   Newcastle United              0              1
# 6403         Tottenham  Manchester United              0              2
#
#       home_score  away_score  home_possession_%  away_possession_%  \
# ...

# %% [markdown]
# ## Data Manipulation

# %%
df[['home_score', 'away_score']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6404 entries, 0 to 6403
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   home_score  6404 non-null   int64
#  1   away_score  6404 non-null   int64
# dtypes: int64(2)
# memory usage: 100.2 KB

# %%
df['result'] = 'D'  # Menginisialisasi semua nilai kolom "result" dengan 'D'
df.loc[df['home_score'] > df['away_score'], 'result'] = 'W'  # Mengubah nilai menjadi 'W' jika home_score > away_score
df.loc[df['home_score'] < df['away_score'], 'result'] = 'L'  # Mengubah nilai menjadi 'L' jika home_score < away_score

# %%
df = df.drop(['home_score', 'away_score'], axis=1)

# %%
df.head()
# Out:
#           home_team         away_team  ht_home_score  ht_away_score  \
# 0  Sheffield United         Liverpool              0              0
# 1        Portsmouth  Blackburn Rovers              1              0
# 2           Everton           Watford              1              0
# 3  Newcastle United    Wigan Athletic              1              0
# 4           Reading     Middlesbrough              2              2
#
#    home_possession_%  away_possession_%  home_shots_on_target  \
# 0               0.41               0.58                     1
# 1               0.44               0.55                    11
# 2               0.46               0.53                     2
# 3               0.55               0.44                     5
# 4               0.52               0.47                     8
#
#    away_shots_on_target  home_shots  away_shots  home_touches  away_touches  \
# 0                     4           6          15           451           569
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.describe()
# Out:
#        ht_home_score  ht_away_score  home_possession_%  away_possession_%  \
# count    6404.000000    6404.000000        6404.000000        6404.000000
# mean        0.682074       0.519519           0.507739           0.483256
# std         0.836903       0.734309           0.111097           0.111096
# min         0.000000       0.000000           0.170000           0.170000
# 25%         0.000000       0.000000           0.430000           0.410000
# 50%         0.000000       0.000000           0.510000           0.480000
# 75%         1.000000       1.000000           0.590000           0.560000
# max         5.000000       5.000000           0.820000           0.820000
#
#        home_shots_on_target  away_shots_on_target   home_shots  away_shots  \
# count           6404.000000           6404.000000  6404.000000  6404.00000
# mean               4.863054              3.942067    14.681761    11.79466
# std                2.642441              2.316497     5.755813     4.93226
# ...

# %% [markdown]
# ### Box Plot

# %%
# Fungsi untuk plotting boxplot
def plot_box(data, labels, title, figsize=(12, 6)):
    sns.set_style("whitegrid")
    plt.figure(figsize=figsize)  # Mengatur ukuran figure
    ax = sns.boxplot(data=data, orient='h', showmeans=True)
    ax.set_xlabel('Value')
    ax.set_title(title)
    ax.set_yticklabels(labels)
    plt.show()

# %%
plot_box(data = df.iloc[:,2:10],
         labels = df.iloc[:, 2:10].columns.tolist(),
         title='Boxplot of Dataset Features')

# %%
plot_box(data = df.iloc[:,10:18],
         labels = df.iloc[:, 10:18].columns.tolist(),
         title='Boxplot of Dataset Features')

# %%
plot_box(data = df.iloc[:, 18:26],
         labels = df.iloc[:, 18:26].columns.tolist(),
         title='Boxplot of Dataset Features')

# %% [markdown]
# ### Distribusi Data

# %%
data = df.iloc[:, :]

rows = 6
cols = 5

fig, axes = plt.subplots(rows, cols, figsize=(20, 10))

# Melakukan flatten pada axes supaya mempermudah iterasi
axes = axes.flatten()

for i, ax in enumerate(axes):
    if i < len(data.columns):
        sns.histplot(data=data, x=data.columns[i], ax=ax)
        ax.set_title(data.columns[i])
    else:
        ax.set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Heatmap Correlation Features Dataset

# %%
# heatmap correlation
corr = df.corr()

plt.figure(figsize=(30,15))
sns.heatmap(corr, annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# ### Check Multikolinearitas

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools import add_constant

X = df[df.iloc[:, 2:28].columns.tolist()]

# Tambahkan sebuah konstanta pada dataframe (prasyarat perhitungan)
X = add_constant(X)

# VIF dataframe
vif_data = pd.DataFrame()

# Hitung VIF tiap fitur
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
vif_data = vif_data[vif_data['feature'] != 'const']

display(vif_data)
# Out:
#                  feature          VIF
# 1          ht_home_score     1.315984
# 2          ht_away_score     1.322641
# 3      home_possession_%  1393.958652
# 4      away_possession_%  1402.016562
# 5   home_shots_on_target     2.246253
# 6   away_shots_on_target     2.162686
# 7             home_shots     2.908864
# 8             away_shots     2.786380
# 9           home_touches    66.140620
# 10          away_touches    65.156773
# 11           home_passes    74.531579
# 12           away_passes    72.830984
# 13          home_tackles     1.392874
# 14          away_tackles     1.376808
# 15       home_clearances     2.362405
# 16       away_clearances     2.523407
# 17          home_corners     1.707100
# 18          away_corners     1.656270
# 19         home_offsides     1.056091
# 20         away_offsides     1.058091
# 21     home_yellow_cards     1.217565
# 22     away_yellow_cards     1.200269
# 23        home_red_cards     1.047223
# 24        away_red_cards     1.037547
# ...

# %%
# df.drop(['home_possession_%', 'away_possession_%', 'home_touches', 'away_touches', 'home_passes', 'away_passes'], axis=1, inplace=True)

# %% [markdown]
# ## Feature Enginerring

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['home_team'] = le.fit_transform(df['home_team'])
df['away_team'] = le.fit_transform(df['away_team'])

# %%
df.head()
# Out:
#    home_team  away_team  ht_home_score  ht_away_score  home_possession_%  \
# 0         32         21              0              0               0.41
# 1         29          3              1              0               0.44
# 2         15         38              1              0               0.46
# 3         26         41              1              0               0.55
# 4         31         25              2              2               0.52
#
#    away_possession_%  home_shots_on_target  away_shots_on_target  home_shots  \
# 0               0.58                     1                     4           6
# 1               0.55                    11                     3          21
# 2               0.53                     2                     7           8
# 3               0.44                     5                     4           8
# 4               0.47                     8                     7          14
#
# ...

# %%
# Scaling Features Dataset
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
cols = df.iloc[:, 2:-1].columns
df[cols] = scaler.fit_transform(df[cols])

# %%
df.head()
# Out:
#    home_team  away_team  ht_home_score  ht_away_score  home_possession_%  \
# 0         32         21            0.0            0.0           0.369231
# 1         29          3            0.2            0.0           0.415385
# 2         15         38            0.2            0.0           0.446154
# 3         26         41            0.2            0.0           0.584615
# 4         31         25            0.4            0.4           0.538462
#
#    away_possession_%  home_shots_on_target  away_shots_on_target  home_shots  \
# 0           0.630769              0.058824              0.266667    0.136364
# 1           0.584615              0.647059              0.200000    0.477273
# 2           0.553846              0.117647              0.466667    0.181818
# 3           0.415385              0.294118              0.266667    0.181818
# 4           0.461538              0.470588              0.466667    0.318182
#
# ...

# %%
# df.iloc[:, :-1].columns

# %% [markdown]
# ## Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

features = df.iloc[:, :-1]
labels = df['result']
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=1000)
rfc.fit(X_train, y_train)
y_pred_rfc = rfc.predict(X_test)
accuracy_rfc = accuracy_score(y_test, y_pred_rfc)

print(f"Predict. results : {y_pred_rfc}")
print(f"Accuracy : {accuracy_rfc}")
# Out:
# Predict. results : ['W' 'W' 'W' ... 'L' 'L' 'W']
# Accuracy : 0.6814988290398126

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            D       0.51      0.27      0.35       315
#            L       0.68      0.74      0.71       370
#            W       0.72      0.86      0.79       596
#
#     accuracy                           0.68      1281
#    macro avg       0.64      0.63      0.62      1281
# weighted avg       0.66      0.68      0.66      1281

# %% [markdown]
# ### K Neighbor Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

knc = KNeighborsClassifier()
knc.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knc = knc.predict(X_test)
accuracy_knc = accuracy_score(y_test, y_pred_knc)

print(f"Predict. results : {y_pred_knc}")
print(f"Accuracy : {accuracy_knc}")
# Out:
# Predict. results : ['W' 'W' 'D' ... 'W' 'D' 'D']
# Accuracy : 0.48633879781420764

# %% [markdown]
# ### Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB

nbc = GaussianNB()
nbc.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred_nbc = nbc.predict(X_test)
accuracy_nbc = accuracy_score(y_test, y_pred_nbc)

print(f"Predict. results : {y_pred_nbc}")
print(f"Accuracy : {accuracy_nbc}")
# Out:
# Predict. results : ['L' 'W' 'D' ... 'W' 'D' 'W']
# Accuracy : 0.6010928961748634

# %% [markdown]
# ### Suppor Vector Classifier

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(X_train, y_train)

# %%
y_pred_svc = svc.predict(X_test)
accuracy_svc = accuracy_score(y_test, y_pred_svc)

print(f"Predict. results : {y_pred_svc}")
print(f"Accuracy : {accuracy_svc}")
# Out:
# Predict. results : ['W' 'W' 'W' ... 'W' 'W' 'W']
# Accuracy : 0.4652615144418423

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dtc = svc.predict(X_test)
accuracy_dtc = accuracy_score(y_test, y_pred_dtc)

print(f"Predict. results : {y_pred_dtc}")
print(f"Accuracy : {accuracy_dtc}")
# Out:
# Predict. results : ['W' 'W' 'W' ... 'W' 'W' 'W']
# Accuracy : 0.4652615144418423

# %% [markdown]
# ## Import Model

# %%
# import pickle 

# with open('model_result.pkl', 'wb') as f :
#     pickle.dump(rfc, f)

# %%
import joblib

joblib.dump(rfc, 'model.joblib')
model = joblib.load('model.joblib')

# %%
# df_encoded = pd.DataFrame(
#         {'Club' : le.classes_.tolist(), 
#          'Code' : sorted(df['home_team'].unique())})
# df_encoded
